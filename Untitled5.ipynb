# %% [markdown]
# <a href="https://colab.research.google.com/github/Mariett-7/programacion1/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # conectores logicos
#
# p and q , p y q se cumplen
#
# p or q, p o q se cumplen
#
# not p, no se cuple p

# %%
edad=17
tiene_cedula = True

if edad >=18 and tiene_cedula:
    print("puedes votar")
else:
    print("no puedes votar")
# Out:
# no puedes votar

# %%
dia = "domingo"
if dia == "sabado" or dia == "domingo":
    print(" es fin de semana")
# Out:
#  es fin de semana

# %%
ia = input("Ingrese el día (L, M, Mi, J, V, S, D): ")

if dia == "S" or dia == "D":
    print("Fin de semana")
elif dia in ["L", "M", "Mi", "J", "V"]:
    print("Entre semana")
else:
    print("Día inválido")
# Out:
# Ingrese el día (L, M, Mi, J, V, S, D): S
# Día inválido

# %%
i = input("Ingrese el día (L, M, Mu, J, V, S, D)")
dia = ["L", "M", "Mi", "J", "V"]
while i in dia:
  print("Entre semana")
  break
else:
  print("Fin de semana")
# Out:
# Ingrese el día (L, M, Mu, J, V, S, D)J
# Entre semana

# %%
usuario = input("Usuario: ")
password = input("Password: ")

if usuario == "admin" and password == "1234":
    print("Acceso permitido")
else:
    print("Acceso denegado")
# Out:
# Usuario: as
# Password: 1234
# Acceso denegado

# %%
a= True
b= True
if a ^ b:
  print("XOR verdadero")
else:
  print("XOR falso")
# Out:
# XOR falso

# %% [markdown]
# **Más sentencias**
#  En python, break se usa para salir inmediatamente de un bucle (for o while) sin esperar a que termine normalmente

# %%
for n in range(0, 10):
  if n == 1 or n == 0:
    print("El número es ", n)
  else:
    for x in range(2, n):
      if n % x == 0:
          print(n, 'es igual a', x, '*', n // x)
          break
    else: # Este else corresponde al for, no al if
      print(n, 'es un número primo')
# Out:
# El número es  0
# El número es  1
# 2 es un número primo
# 3 es un número primo
# 4 es igual a 2 * 2
# 5 es un número primo
# 6 es igual a 2 * 3
# 7 es un número primo
# 8 es igual a 2 * 4
# 9 es igual a 3 * 3

# %%
lista = [10, 20, 30]
try:
    index = int(input("Ingresa un índice: "))
    print("El valor es:", lista[index])
except IndexError: # Indice fuera de rango
    print("Índice fuera de rango")
except ValueError: # Cuando ingresamos un valor no permitido
    print("Debes ingresar un número entero")
# Out:
# Ingresa un índice: 2
# El valor es: 30

# %%
tupla=(3,67,54,23,12)
try:
    index = int(input("Ingresa un índice: "))
    print("El valor es:", tupla[index])
except IndexError: # Indice fuera de rango
    print("Índice fuera de rango")
except ValueError: # Cuando ingresamos un valor no permitido
    print("Debes ingresar un número entero")
# Out:
# Ingresa un índice: 5
# Índice fuera de rango

# %%
palabra="murcielago"
try:
    letra = str(input("Ingresa una letra: "))
    if letra in palabra
    print(" la letra encontrada es :", letra)
    elif letra not in palabra:
        print("la letra no se encuentra en la palabra")
        else:
        print("Debes ingresar una letra")
except: ValueErrorError:
    print("Debes ingresar una letra")
# Out:
#   File "/tmp/ipython-input-3091763121.py", line 4
#     if letra in palabra
#                        ^
# SyntaxError: expected ':'

# %%
clave_correcta = "python123"
intento = ""
while intento != clave_correcta:
    intento = input("Ingresa la contraseña: ")
print("¡Acceso concedido!")
# Out:
# Ingresa la contraseña: python123
# ¡Acceso concedido!

# %%
clave_correcta = "python123"
intentos = 3
while intentos > 0:
    intento = input("Ingresa la contraseña: ")
    if intento == clave_correcta:
      print("¡Acceso concedido!")
      break
    else:
      intentos -= 1
    print("intentos restantes:", intentos)
else:
  print("cuenta bloqueada")
# Out:
# Ingresa la contraseña: casa
# intentos restantes: 2
# Ingresa la contraseña: tengo sueño
# intentos restantes: 1
# Ingresa la contraseña: python123
# intentos restantes: 0
# cuenta bloqueada
